# %%
import pandas as pd
import numpy as np

mydata= pd.read_csv('C://Users//Gautam Ruikar//Downloads//FinalData.csv')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata['Body'] = mydata['Body'].str.strip('<p>')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata['Body'] = mydata['Body'].str.strip('""')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata['Body'] = mydata['Body'].str.strip(' ')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata['Body'] = mydata['Body'].str.strip('\n')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata['Body'] = mydata['Body'].str.replace('>', '')
display(mydata)
# Out:
#                 ID  PostTypeId  AcceptedAnswerId  ParentId      CreationDate  \
# 0         927358.0           1          927386.0       NaN  29-05-2009 18:09
# 1        2003505.0           1         2003515.0       NaN  05-01-2010 01:12
# 2        5767325.0           1         5767357.0       NaN  23-04-2011 22:17
# 3       16956810.0           1        16957078.0       NaN  06-06-2013 08:06
# 4        2906582.0           1         2906586.0       NaN  25-05-2010 16:39
# ...            ...         ...               ...       ...               ...
# 199996  52253192.0           1        52264568.0       NaN  10-09-2018 07:44
# 199997     26151.0           1           26162.0       NaN  25-08-2008 14:47
# 199998  37141516.0           1        55449823.0       NaN  10-05-2016 14:31
# 199999  12005526.0           1        22312983.0       NaN  17-08-2012 12:10
# 200000  11041961.0           1               NaN       NaN  14-06-2012 22:00
#
#         DeletionDate  Score  ViewCount  \
# ...

# %%
mydata.to_csv('file_name.csv', index=False)
